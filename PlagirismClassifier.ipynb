# %% [markdown]
# # Multiclass classification
# > Can use either one versus one approach or one versus many approach using SVM or use Neuronetwork(ie CNN)
#
# https://machinelearningmastery.com/one-vs-rest-and-one-vs-one-for-multi-class-classification/
#
# https://github.com/wolfgarbe/SymSpellCompound
#
# https://towardsdatascience.com/symspellcompound-10ec8f467c9b
#
# file:///C:/Users/swcam/Downloads/SIGIR2015TalkVulicMoensSlides.pdf
#
# https://github.com/mr-mf/plagiarism-detector/blob/master/2_Plagiarism_Feature_Engineering.ipynb
#
# https://github.com/kukaraj/udacity-mlnd-plagirism-detector/blob/master/2_Plagiarism_Feature_Engineering.ipynb

# %%
#Upload your train/test feature data


    #Upload your train/test feature data
    #Define a binary classification model and a training script.
    #Train your model and deploy it 
    #Evaluate your deployed classifier.

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
@author: Carlos

"""
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import pandas, xgboost, numpy, textblob, string
from keras.preprocessing import text, sequence
from keras import layers, models, optimizers
import spacy

# %% [markdown]
# # Upload training and valid/test data
#
# The data is uploaded in a format that is ready to be put in to the model with features included

# %%
# Labels are in the first column
train_y = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/train_y.csv")
train_x = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/training_xx.csv")

#valid_data = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/train.csv")

# Labels are in the first column
valid_y = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/valid_y.csv")
valid_x = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/valid_xx.csv")

xtrain_count = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/xtrain_count.csv")
xvalid_count = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/xvalid_count.csv")

xtrain_tfidf = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/xtrain_tfidf.csv")
xvalid_tfidf = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/xvalid_tfidf.csv")

xtrain_tfidf_ngram = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/xtrain_tfidf_ngram.csv")
xvalid_tfidf_ngram = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/xvalid_tfidf_ngram.csv")

xtrain_tfidf_ngram_chars = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/xtrain_tfidf_ngram_chars.csv")
xvalid_tfidf_ngram_chars = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/xvalid_tfidf_ngram_chars.csv")

features_train_all = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/features_train_all.csv")
features_valid_all = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/features_valid_all.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-98637f785997> in <module>()
# ----> 1 train_y = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/train_y.csv")
#       2 train_x = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/training_xx.csv")
#       3
#       4 #valid_data = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/test_training_files/train.csv")
#       5
#
# ...

# %%
xtrain_count = train_x
xvalid_count = valid_x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fb51073cf692> in <module>()
# ----> 1 xtrain_count = train_x
#       2 xvalid_count = valid_x
#
# NameError: name 'train_x' is not defined

# %%
xtrain_count.dtypes
# Out:
# -1                     int64
# -1.1                   int64
# 0.229                float64
# 0.105                float64
# 0.666                float64
# 0.97585              float64
# 877.0                float64
# 137.0                float64
# 6.355072463768116    float64
# 52.0                 float64
# 13.0                 float64
# 25.0                 float64
# 3.0                  float64
# 1.0                  float64
# dtype: object

# %% [markdown]
# # Build Model

# %%
#    
#    
# Model Building
   # fit the training dataset on the classifier 
def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
   # fit the training dataset on the classifier 
  classifier.fit(feature_vector_train, label)

  # predict the labels on validation dataset
  predictions = classifier.predict(feature_vector_valid)

  if is_neural_net:
      predictions = predictions.argmax(axis=-1)

  return metrics.accuracy_score(predictions, valid_y)  

## If you'd like to output precision, recall, F-score, etc.  
##  See https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html

# %% [markdown]
# # Classifiers

# %% [markdown]
# 1.   Naive Bayes
# 2.   SVM
# 3.   Recurrent Neural Network: LSTM
# 4.   Recurrent Convolutional Neural Network

# %%
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_count, train_y, xvalid_count)
print ("NB, Count Vectors: ", accuracy)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-63c82b8d1f11> in <module>()
# ----> 1 accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_count, train_y, xvalid_count)
#       2 print ("NB, Count Vectors: ", accuracy)
#
# <ipython-input-5-db82612c022a> in train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net)
#       1 def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
#       2    # fit the training dataset on the classifier
# ----> 3   classifier.fit(feature_vector_train, label)
#       4
# ...

# %% [markdown]
# # Naive Bayes

# %%
# Naive Bayes on Count Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_count, train_y, xvalid_count)
print ("NB, Count Vectors: ", accuracy)

# Naive Bayes on Word Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf, train_y, xvalid_tfidf)
print ( "NB, WordLevel TF-IDF: ", accuracy)

# Naive Bayes on Ngram Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf_ngram, train_y, xvalid_tfidf_ngram)
print ("NB, N-Gram Vectors: ", accuracy)

# Naive Bayes on Character Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf_ngram_chars, train_y, xvalid_tfidf_ngram_chars)
print ("NB, CharLevel Vectors: ", accuracy)

# %% [markdown]
# # SVM

# %%
accuracy = train_model(svm.SVC(), xtrain_tfidf_ngram, train_y, xvalid_tfidf_ngram)
print ("SVM, N-Gram Vectors: ", accuracy)

# %%
accuracy = train_model(svm.SVC(), train_x, train_y, valid_y)
print ("SVM, N-Gram Vectors: ", accuracy)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-16d4f0156d87> in <module>()
# ----> 1 accuracy = train_model(svm.SVC(), train_x, train_y, valid_y)
#       2 print ("SVM, N-Gram Vectors: ", accuracy)
#
# <ipython-input-5-db82612c022a> in train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net)
#       4
#       5   # predict the labels on validation dataset
# ----> 6   predictions = classifier.predict(feature_vector_valid)
#       7
#       8   if is_neural_net:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py in predict(self, X)
# ...

# %% [markdown]
# # HyperParameters
#
#
# *   Parameters that can be modified to train ML model
# *   epochs =  150,hidden_dim = 20,input_features = 4,output_dim =1

# %% [markdown]
# # Recurrent Neural Network: LSTM

# %%
def create_rnn_lstm():
    # Add an Input Layer
    input_layer = layers.Input((70, ))

    # Add the word embedding Layer
    embedding_layer = layers.Embedding(len(word_index) + 1, 300, weights=[embedding_matrix], trainable=False)(input_layer)
    embedding_layer = layers.SpatialDropout1D(0.3)(embedding_layer)

    # Add the LSTM Layer
    lstm_layer = layers.LSTM(100)(embedding_layer)

    # Add the output Layers
    output_layer1 = layers.Dense(50, activation="relu")(lstm_layer)
    output_layer1 = layers.Dropout(0.25)(output_layer1)
    output_layer2 = layers.Dense(1, activation="sigmoid")(output_layer1)

    # Compile the model
    model = models.Model(inputs=input_layer, outputs=output_layer2)
    model.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy')
    
    return model

classifier = create_rnn_lstm()
accuracy = train_model(classifier, train_seq_x, train_y, valid_seq_x, is_neural_net=True)
print ("RNN-LSTM, Word Embeddings",  accuracy)

# %% [markdown]
# # Recurrent Convolutional Neural Network

# %%
def create_rcnn():
    # Add an Input Layer
    input_layer = layers.Input((70, ))

    # Add the word embedding Layer
    embedding_layer = layers.Embedding(len(word_index) + 1, 300, weights=[embedding_matrix], trainable=False)(input_layer)
    embedding_layer = layers.SpatialDropout1D(0.3)(embedding_layer)
    
    # Add the recurrent layer: not sure it's needed here
    rnn_layer = layers.Bidirectional(layers.GRU(50, return_sequences=True))(embedding_layer)
    
    # Add the convolutional Layer
    conv_layer = layers.Convolution1D(100, 3, activation="relu")(embedding_layer)

    # Add the pooling Layer
    pooling_layer = layers.GlobalMaxPool1D()(conv_layer)

    # Add the output Layers
    output_layer1 = layers.Dense(50, activation="relu")(pooling_layer)
    output_layer1 = layers.Dropout(0.25)(output_layer1)
    output_layer2 = layers.Dense(1, activation="sigmoid")(output_layer1)

    # Compile the model
    model = models.Model(inputs=input_layer, outputs=output_layer2)
    model.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy')
    
    return model

classifier = create_rcnn()
accuracy = train_model(classifier, train_seq_x, train_y, valid_seq_x, is_neural_net=True)
print ("RCNN, Word Embeddings",  accuracy)

# %% [markdown]
# # Store model
# The process of saving an object to be re-used later is called serialization, while loading a saved object is called deserialization
#
# *   Use pickle to store model
# *   Use pick to deploy model
