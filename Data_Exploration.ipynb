# %%
#Step 1 of the project

# %%
#Load in the corpus of plagiarism text data.
#Explore the existing data features and the data distribution.

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# Have to mount my drive otherwise I cannot import data from drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# # French Essays

# %%
csv_file = '/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/CrossLanguageDocsAndTranslations .csv'
plagiarism_df = pd.read_csv(csv_file)

# print out the first few rows of data info
plagiarism_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-34781257a0ac> in <module>()
#       1 csv_file = '/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/CrossLanguageDocsAndTranslations .csv'
# ----> 2 plagiarism_df = pd.read_csv(csv_file)
#       3
#       4 # print out the first few rows of data info
#       5 plagiarism_df.head(10)
#
# ...

# %%
len(plagiarism_df)
# Out:
# 99

# %%
# print out some stats about the data
print('Number of files: ', plagiarism_df.shape[0])  # .shape[0] gives the rows 
# .unique() gives unique items in a specified column
print('Number of unique tasks/question types : ', (len(plagiarism_df['Label'].unique())))
print('Unique plagiarism categories: ', (plagiarism_df['Label'].unique()))
print('The orignal text is in French and has been translated to English by human and machine translation')
# Out:
# Number of files:  99
# Number of unique tasks/question types :  3
# Unique plagiarism categories:  ['French' 'English' 'TEng']
# The orignal text is in French and has been translated to English by human and machine translation

# %%
# count by label
counts_per_task=plagiarism_df.groupby(['Label']).size().reset_index(name="Counts")
print("\nTask:")
display(counts_per_task)
# Out:
# Task:
#      Label  Counts
# 0  English      33
# 1   French      33
# 2     TEng      33

# %% [markdown]
# # English Essays

# %%
csv_file = '/content/drive/My Drive/Colab Notebooks/CrossLanguagePlagirism/English Essays.csv'
plagiarism_df = pd.read_csv(csv_file)

# print out the first few rows of data info
plagiarism_df.head(10)
# Out:
#                                             EN ESSAY
# 0  There have been many studies in which research...
# 1  Decision tree induction is one of the useful a...
# 2  This paper firstly analyses the actual underwr...
# 3  This paper presents a novel machine learning m...
# 4  Determination of model complexity is a challen...
# 5  Stock market or Share market is one of the mos...
# 6  We have investigated the risk factors that lea...
# 7  This work proposes an intelligent learning dia...
# 8  Semi-supervised support vector machine is an e...
# 9  Transfer learning aims to improve a targeted l...
